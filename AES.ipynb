# %%
#AES Encryption
import numpy as np
plain = input("Plain Text of 128bits(16 characters):")
k0 = input("Key of 128bits(16 characters): ")
#plain = "amartya   raghav"
#k0 = "implementing aes"
key = ['']*len(k0)

def inverse(n):    
    for d in range(0,26):
        inv=0
        if(d*n)%26==1:
            inv=d
        return inv

w = np.zeros([4,4],dtype=int)
p = np.zeros([4,4],dtype=int)
a = np.zeros([4,4],dtype=int)
b = np.zeros([4,4],dtype=int)
c = np.zeros([4,4],dtype=int)
k = np.zeros([1,4],dtype=int)
m =[[int('02',16),int('03',16),int('01',16),int('01',16)],[int('01',16),int('02',16),int('03',16),int('01',16)],[int('01',16),int('01',16),int('02',16),int('03',16)],[int('03',16),int('01',16),int('01',16),int('02',16)]]
rc=[int('01',16),int('02',16),int('04',16),int('08',16),int('10',16),int('20',16),int('40',16),int('80',16),int('1b',16),int('36',16)]
sbox = [
        
        ]

sboxInv = [
        
        ]

cipher=""
#print(m)
z=0
for y in range(4):
    for x in range(4):
        p[x][y]= (ord(plain[z]))
        w[x][y]= (ord(k0[z]))
        #print(w)
        z+=1
print("plain text:")
print(p)
print("R0 Key:")
print(w)
#print(int(w[0][1],16))#converting back to decimal
#Addition of first round key
a=np.bitwise_xor(p,w)
print("A matrix:")
print(a)
#Round starts
for i in range(10):
#Byte Substitution - Needs correction
    for z in range(4):
        for y in range(4):
            b[y][z]= inverse(a[y][z])
   # print(b)
#Shift Rows
    b=a # must be changed to b after correction in byte substitution
#print(c)
    b[1]=np.roll(b[1],-1)
    b[2]=np.roll(b[2],-2)
    b[3]=np.roll(b[3],-3)
    print("After Shift rows:")
    print(b)
#Mix Columns- not in last round
    if i<9:
        c=np.multiply(m,b)
        print("After Mix Columns:")
        print(c)
#Key Generation
    #gfunction
    for l in range(4):
        #for m in range(4):
        k=np.roll(w[l],-1)
            #for h in range(4):
             #   for f in range(4):
              #      k[f]=inverse(k[f])   #Needs correction for Shift box inverse value 
        k=np.bitwise_xor(k,[rc[i],0,0,0])
        #print("gfunction output for round %d:" %(i+1)) 
        #print(k)
        w[l]=np.bitwise_xor(w[l],k)
    print("Key after round %d" %(i+1))
    print(w)
#Add Key
    a=np.bitwise_xor(c,w)
    print("result after round %d" %(i+1))
    print(a)
#Converting to cipher text
for k in range(4):
    for t in range(4):
        cipher+=chr((a[t][k])%26+65)
print("Cipher Text:")
print(cipher)
# Out:
# Plain Text of 128bits(16 characters):oksoyouwereright
# Key of 128bits(16 characters): oksoyouwerewrong
# plain text:
# [[111 121 101 105]
#  [107 111 114 103]
#  [115 117 101 104]
#  [111 119 114 116]]
# R0 Key:
# [[111 121 101 114]
#  [107 111 114 111]
#  [115 117 101 110]
#  [111 119 119 103]]
# A matrix:
# [[ 0  0  0 27]
#  [ 0  0  0  8]
#  [ 0  0  0  6]
#  [ 0  0  5 19]]
# After Shift rows:
# [[ 0  0  0 27]
#  [ 0  0  8  0]
#  [ 0  6  0  0]
#  [19  0  0  5]]
# After Mix Columns:
# [[ 0  0  0 27]
#  [ 0  0 24  0]
#  [ 0  6  0  0]
#  [57  0  0 10]]
# Key after round 1
# [[23 28 23 29]
#  [ 5 29 29  4]
#  [ 7 16 11 29]
#  [25  0 16  8]]
# result after round 1
# [[23 28 23  6]
#  [ 5 29  5  4]
#  [ 7 22 11 29]
#  [32  0 16  2]]
# After Shift rows:
# [[23 28 23  6]
#  [29  5  4  5]
#  [11 29  7 22]
#  [ 2 32  0 16]]
# After Mix Columns:
# [[46 84 23  6]
#  [29 10 12  5]
#  [11 29 14 66]
#  [ 6 32  0 32]]
# Key after round 2
# [[ 9 11 10 10]
#  [26  0 25  1]
#  [21 27 22 26]
# ...

# %%
dec = 255
h =hex(dec)
print(type(h))
print(h)

print(int(h,16))
# Out:
# <class 'str'>
# 0xff
# 255

# %%
print(hex(int('0x74',16)^int('0x69',16)))
print(inverse(8))
# Out:
# 0x1d
# 0
